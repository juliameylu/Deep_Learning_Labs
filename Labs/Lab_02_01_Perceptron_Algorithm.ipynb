# %% [markdown]
# ### Lab 2.1: Perceptron Algorithm
#
# In this lab you will implement the perceptron algorithm presented in lecture using NumPy.

# %%
# !pip install -q -r https://raw.githubusercontent.com/calpoly-data4620/DATA-4620-Labs/refs/heads/main/requirements.txt

# %%
import numpy as np
from palmerpenguins import load_penguins
from mlxtend.plotting import plot_decision_regions
from matplotlib import pyplot as plt

# %% [markdown]
# Here we loading and format the Palmer penguins dataset for binary classification.

# %%
df = load_penguins()

# drop rows with missing values
df.dropna(inplace=True)

# tricky code to randomly shuffle the rows
df = df.sample(frac=1).reset_index(drop=True)

# select only two specices
df = df[(df['species']=='Adelie')|(df['species']=='Chinstrap')]

# get two features
X = df[['flipper_length_mm','bill_length_mm']].values

# convert speces labels to 0 and 1
y = df['species'].map({'Adelie':0,'Chinstrap':1}).values

# %% [markdown]
# To make the learning algorithm work more smoothly, we we will subtract the mean of each feature.
#
# Here `np.mean` calculates a mean, and `axis=0` tells NumPy to calculate the mean over the rows (calculate the mean of each column).

# %%
X -= np.mean(X,axis=0)

# %% [markdown]
# ### Exercises
#
# Your task is to complete this class for the perceptron.  Fill in the `train_step`, `predict`, and `score` functions.

# %%
class Perceptron:
    def __init__(self,lr=1e-3):
        # store the learning rate
        self.lr = lr

        # initialize the weights to small, normally-distributed values
        self.w = np.random.normal(size=(2,))*0.01

        # initialize the bias to zero
        self.b = 0

    def train_step(self,x,y):
        """ Apply the least squares update rule shown in lecture.
            Arguments:
             x: data point of shape (2,)
             y: label 
        """
        # WRITE CODE HERE
        # hint: first convert the y values to -1 or 1 using arithmetic or np
        y = 1 if y > 0 else -1
        z = self.w.T @ x + self.b

        self.w += self.lr * (y - z) * x
        self.b += self.lr * (y - z)
        

    
    def predict(self,X):
        """ Calculate model prediction for all data points.
            
            Arguments:
             X: data matrix of shape (N,2)   
            Returns:
             Predicted labels (0 or 1) of shape (N,)
        """
        # WRITE CODE HERE
        z = X @ self.w + self.b
        return np.where(z > 0, 1, 0)
    
    def score(self,X,y):
        """ Calculate model accuracy
            Arguments:
             X: data matrix of shape (N,2)   
             y: labels of shape (N,)
            Returns:
             Accuracy score
        """
        # WRITE CODE HERE
        y_pred = self.predict(X)
        return np.mean(y_pred == y)

# %% [markdown]
# Run the following code to train the model and print out the accuracy at each step.

# %%
model = Perceptron()
for i in range(len(X)):
    model.train_step(X[i],y[i])
    print(f'step {i}: {model.score(X,y)}')
# Out:
# step 0: 0.411214953271028
# step 1: 0.7616822429906542
# step 2: 0.7383177570093458
# step 3: 0.7570093457943925
# step 4: 0.8364485981308412
# step 5: 0.883177570093458
# step 6: 0.8411214953271028
# step 7: 0.8411214953271028
# step 8: 0.8457943925233645
# step 9: 0.8364485981308412
# step 10: 0.8364485981308412
# step 11: 0.794392523364486
# step 12: 0.7990654205607477
# step 13: 0.8130841121495327
# step 14: 0.8130841121495327
# step 15: 0.8364485981308412
# step 16: 0.8364485981308412
# step 17: 0.8317757009345794
# step 18: 0.8317757009345794
# step 19: 0.8271028037383178
# step 20: 0.8271028037383178
# step 21: 0.8364485981308412
# step 22: 0.8411214953271028
# step 23: 0.8411214953271028
# step 24: 0.8411214953271028
# step 25: 0.8598130841121495
# step 26: 0.8551401869158879
# step 27: 0.8551401869158879
# step 28: 0.8598130841121495
# step 29: 0.8598130841121495
# step 30: 0.8598130841121495
# step 31: 0.8598130841121495
# step 32: 0.883177570093458
# step 33: 0.8644859813084113
# step 34: 0.8598130841121495
# step 35: 0.8598130841121495
# step 36: 0.8691588785046729
# step 37: 0.8598130841121495
# step 38: 0.8551401869158879
# step 39: 0.8785046728971962
# step 40: 0.8785046728971962
# step 41: 0.8785046728971962
# step 42: 0.8785046728971962
# step 43: 0.8785046728971962
# step 44: 0.8785046728971962
# step 45: 0.8785046728971962
# step 46: 0.8785046728971962
# step 47: 0.8785046728971962
# step 48: 0.8785046728971962
# step 49: 0.8691588785046729
# step 50: 0.8785046728971962
# step 51: 0.8785046728971962
# step 52: 0.8738317757009346
# step 53: 0.8738317757009346
# step 54: 0.8785046728971962
# step 55: 0.8785046728971962
# step 56: 0.8785046728971962
# step 57: 0.8785046728971962
# step 58: 0.883177570093458
# step 59: 0.883177570093458
# step 60: 0.883177570093458
# step 61: 0.883177570093458
# step 62: 0.8785046728971962
# step 63: 0.8785046728971962
# step 64: 0.8785046728971962
# step 65: 0.8785046728971962
# step 66: 0.8785046728971962
# step 67: 0.8785046728971962
# step 68: 0.8785046728971962
# step 69: 0.9158878504672897
# step 70: 0.9112149532710281
# step 71: 0.8925233644859814
# step 72: 0.8925233644859814
# step 73: 0.8925233644859814
# step 74: 0.883177570093458
# step 75: 0.8785046728971962
# step 76: 0.8785046728971962
# step 77: 0.883177570093458
# step 78: 0.8785046728971962
# step 79: 0.8785046728971962
# step 80: 0.8785046728971962
# step 81: 0.883177570093458
# step 82: 0.883177570093458
# step 83: 0.883177570093458
# step 84: 0.883177570093458
# step 85: 0.8785046728971962
# step 86: 0.8785046728971962
# step 87: 0.8785046728971962
# step 88: 0.883177570093458
# step 89: 0.883177570093458
# step 90: 0.883177570093458
# step 91: 0.883177570093458
# step 92: 0.8785046728971962
# step 93: 0.8785046728971962
# step 94: 0.883177570093458
# step 95: 0.883177570093458
# step 96: 0.8925233644859814
# step 97: 0.8925233644859814
# step 98: 0.8925233644859814
# step 99: 0.8925233644859814
# step 100: 0.9392523364485982
# step 101: 0.9345794392523364
# step 102: 0.9299065420560748
# step 103: 0.9299065420560748
# step 104: 0.9299065420560748
# step 105: 0.9345794392523364
# step 106: 0.9299065420560748
# step 107: 0.9345794392523364
# step 108: 0.9205607476635514
# step 109: 0.9205607476635514
# step 110: 0.9392523364485982
# step 111: 0.9345794392523364
# step 112: 0.9392523364485982
# step 113: 0.9345794392523364
# step 114: 0.9345794392523364
# step 115: 0.9439252336448598
# step 116: 0.9345794392523364
# step 117: 0.9345794392523364
# step 118: 0.9345794392523364
# step 119: 0.9345794392523364
# step 120: 0.9345794392523364
# step 121: 0.9252336448598131
# step 122: 0.9299065420560748
# step 123: 0.9112149532710281
# step 124: 0.9112149532710281
# step 125: 0.9112149532710281
# step 126: 0.9112149532710281
# step 127: 0.9112149532710281
# step 128: 0.9205607476635514
# step 129: 0.9205607476635514
# step 130: 0.9252336448598131
# step 131: 0.9205607476635514
# step 132: 0.9252336448598131
# step 133: 0.9252336448598131
# step 134: 0.9345794392523364
# step 135: 0.9252336448598131
# step 136: 0.9345794392523364
# step 137: 0.9345794392523364
# step 138: 0.9439252336448598
# step 139: 0.9439252336448598
# step 140: 0.9299065420560748
# step 141: 0.9299065420560748
# step 142: 0.9345794392523364
# step 143: 0.9299065420560748
# step 144: 0.9299065420560748
# step 145: 0.9345794392523364
# step 146: 0.9345794392523364
# step 147: 0.9345794392523364
# step 148: 0.9345794392523364
# step 149: 0.9252336448598131
# step 150: 0.9345794392523364
# step 151: 0.9392523364485982
# step 152: 0.9345794392523364
# step 153: 0.9392523364485982
# step 154: 0.9392523364485982
# step 155: 0.9392523364485982
# step 156: 0.9345794392523364
# step 157: 0.9439252336448598
# step 158: 0.9392523364485982
# step 159: 0.9392523364485982
# step 160: 0.9392523364485982
# step 161: 0.9392523364485982
# step 162: 0.9392523364485982
# step 163: 0.9252336448598131
# step 164: 0.9252336448598131
# step 165: 0.9158878504672897
# step 166: 0.9158878504672897
# step 167: 0.8878504672897196
# step 168: 0.9252336448598131
# step 169: 0.9252336448598131
# step 170: 0.9252336448598131
# step 171: 0.9252336448598131
# step 172: 0.9205607476635514
# step 173: 0.9252336448598131
# step 174: 0.9392523364485982
# step 175: 0.9392523364485982
# step 176: 0.9439252336448598
# step 177: 0.9345794392523364
# step 178: 0.9205607476635514
# step 179: 0.9252336448598131
# step 180: 0.9439252336448598
# step 181: 0.9345794392523364
# step 182: 0.9439252336448598
# step 183: 0.9345794392523364
# step 184: 0.9345794392523364
# step 185: 0.9252336448598131
# step 186: 0.9205607476635514
# step 187: 0.9252336448598131
# step 188: 0.9158878504672897
# step 189: 0.9252336448598131
# step 190: 0.9252336448598131
# step 191: 0.9252336448598131
# step 192: 0.9158878504672897
# step 193: 0.9252336448598131
# step 194: 0.9439252336448598
# step 195: 0.9439252336448598
# step 196: 0.9439252336448598
# step 197: 0.9439252336448598
# step 198: 0.9439252336448598
# step 199: 0.9532710280373832
# step 200: 0.9485981308411215
# step 201: 0.9485981308411215
# step 202: 0.9439252336448598
# step 203: 0.9439252336448598
# step 204: 0.9532710280373832
# step 205: 0.9485981308411215
# step 206: 0.9579439252336449
# step 207: 0.9485981308411215
# step 208: 0.9439252336448598
# step 209: 0.9439252336448598
# step 210: 0.9579439252336449
# step 211: 0.9532710280373832
# step 212: 0.9532710280373832
# step 213: 0.9485981308411215

# %% [markdown]
# Finally we plot the decision regions.

# %%
plot_decision_regions(X, y, clf=model, legend=0, markers='o')
# Out:
# <Axes: >
